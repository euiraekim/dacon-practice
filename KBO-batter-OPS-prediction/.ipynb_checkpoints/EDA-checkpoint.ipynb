# %%
from matplotlib import font_manager, rc
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import platform

# %%
pd.set_option('max_columns', 50)
# %matplotlib inline

# %%
if platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    rc('font', family='AppleGothic')
    
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
preseason_df = pd.read_csv('./data/Pre_Season_Batter.csv')
regular_season_df = pd.read_csv('./data/Regular_Season_Batter.csv')

# %%
print(preseason_df.shape)
display(preseason_df.head())
# Out:
# (1393, 29)
#    batter_id batter_name  year team    avg   G  AB  R  H  2B  3B  HR  TB  RBI  \
# 0          0        가르시아  2018   LG  0.350   7  20  1  7   1   0   1  11    5
# 1          1         강경학  2011   한화  0.000   4   2  2  0   0   0   0   0    1
# 2          1         강경학  2014   한화      -   4   0  2  0   0   0   0   0    0
# 3          1         강경학  2015   한화  0.130  10  23  3  3   0   0   0   3    1
# 4          1         강경학  2016   한화  0.188  14  32  4  6   1   1   0   9    2
#
#    SB  CS  BB  HBP  SO  GDP    SLG    OBP  E height/weight      year_born  \
# 0   0   0   2    0   3    1  0.550  0.409  1    177cm/93kg  1985년 04월 12일
# 1   0   1   0    2   1    0  0.000  0.500  0    180cm/72kg  1992년 08월 11일
# 2   0   0   0    0   0    0    NaN    NaN  0    180cm/72kg  1992년 08월 11일
# 3   3   0   4    1   9    0  0.130  0.286  2    180cm/72kg  1992년 08월 11일
# 4   1   2   0    1  10    0  0.281  0.212  0    180cm/72kg  1992년 08월 11일
#
#     position                                  career starting_salary    OPS
# 0  내야수(우투우타)  쿠바 Ciego de Avila Maximo Gomez Baez(대)             NaN  0.959
# 1  내야수(우투좌타)                       광주대성초-광주동성중-광주동성고         10000만원  0.500
# 2  내야수(우투좌타)                       광주대성초-광주동성중-광주동성고         10000만원    NaN
# 3  내야수(우투좌타)                       광주대성초-광주동성중-광주동성고         10000만원  0.416
# 4  내야수(우투좌타)                       광주대성초-광주동성중-광주동성고         10000만원  0.493

# %%
preseason_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393 entries, 0 to 1392
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   batter_id        1393 non-null   int64
#  1   batter_name      1393 non-null   object
#  2   year             1393 non-null   int64
#  3   team             1393 non-null   object
#  4   avg              1393 non-null   object
#  5   G                1393 non-null   int64
#  6   AB               1393 non-null   int64
#  7   R                1393 non-null   int64
#  8   H                1393 non-null   int64
#  9   2B               1393 non-null   int64
#  10  3B               1393 non-null   int64
#  11  HR               1393 non-null   int64
#  12  TB               1393 non-null   int64
#  13  RBI              1393 non-null   int64
#  14  SB               1393 non-null   int64
#  15  CS               1393 non-null   int64
#  16  BB               1393 non-null   int64
#  17  HBP              1393 non-null   int64
#  18  SO               1393 non-null   int64
#  19  GDP              1393 non-null   int64
#  20  SLG              1364 non-null   float64
#  21  OBP              1368 non-null   float64
#  22  E                1393 non-null   int64
#  23  height/weight    1393 non-null   object
#  24  year_born        1393 non-null   object
#  25  position         1393 non-null   object
#  26  career           1393 non-null   object
#  27  starting_salary  1179 non-null   object
#  28  OPS              1364 non-null   float64
# dtypes: float64(3), int64(18), object(8)
# memory usage: 315.7+ KB

# %%
display(preseason_df.describe())
# Out:
#          batter_id         year            G           AB            R  \
# count  1393.000000  1393.000000  1393.000000  1393.000000  1393.000000
# mean    173.434314  2013.014358     8.705671    19.201723     2.679828
# std      94.716851     4.166757     5.562686    13.395946     2.637212
# min       0.000000  2002.000000     1.000000     0.000000     0.000000
# 25%      99.000000  2010.000000     6.000000     9.000000     1.000000
# 50%     178.000000  2014.000000     9.000000    18.000000     2.000000
# 75%     254.000000  2017.000000    11.000000    28.000000     4.000000
# max     344.000000  2018.000000   119.000000   183.000000    35.000000
#
#                  H           2B           3B           HR           TB  \
# count  1393.000000  1393.000000  1393.000000  1393.000000  1393.000000
# mean      5.021536     0.954774     0.119885     0.391960     7.391960
# std       4.232584     1.196904     0.379976     0.748557     6.538787
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.000000     0.000000     2.000000
# 50%       4.000000     1.000000     0.000000     0.000000     6.000000
# 75%       8.000000     2.000000     0.000000     1.000000    11.000000
# max      51.000000    11.000000     4.000000     5.000000    68.000000
#
#                RBI           SB           CS           BB          HBP  \
# count  1393.000000  1393.000000  1393.000000  1393.000000  1393.000000
# mean      2.430725     0.629576     0.291457     1.877961     0.330223
# std       2.698122     1.146854     0.595522     2.053392     0.642204
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       2.000000     0.000000     0.000000     1.000000     0.000000
# 75%       4.000000     1.000000     0.000000     3.000000     1.000000
# max      24.000000     9.000000     4.000000    21.000000     4.000000
#
#                 SO          GDP          SLG          OBP            E  \
# count  1393.000000  1393.000000  1364.000000  1368.000000  1393.000000
# mean      3.714286     0.447236     0.361012     0.317912     0.381910
# std       3.180884     0.723364     0.269892     0.151489     0.729521
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.217000     0.250000     0.000000
# 50%       3.000000     0.000000     0.344500     0.333000     0.000000
# 75%       5.000000     1.000000     0.478000     0.400000     1.000000
# max      36.000000     5.000000     4.000000     1.000000     5.000000
#
#                OPS
# count  1364.000000
# mean      0.676924
# std       0.386933
# min       0.000000
# 25%       0.472000
# 50%       0.675000
# 75%       0.867000
# max       5.000000

# %%
preseason_df.hist(figsize=(10, 9))
plt.tight_layout()
plt.show()

# %%
regular_season_df.hist(figsize=(10, 9))
plt.tight_layout()
plt.show()

# %%
regular_count = regular_season_df.groupby('year')['batter_id'].count().rename('regular')
preseason_count = preseason_df.groupby('year')['batter_id'].count().rename('preseason')
pd.concat([regular_count, preseason_count, np.round(preseason_count/regular_count, 2).rename('ratio')],
          axis=1).transpose().loc[:,2002:]
# Out:
# year        2002   2003   2004   2005   2006   2007    2008    2009    2010  \
# regular    43.00  54.00  68.00  73.00  85.00  98.00  115.00  124.00  130.00
# preseason  12.00  19.00  28.00  37.00  36.00  43.00   61.00   66.00   72.00
# ratio       0.28   0.35   0.41   0.51   0.42   0.44    0.53    0.53    0.55
#
# year        2011   2012    2013    2014    2015    2016    2017   2018
# regular    151.0  174.0  194.00  186.00  207.00  213.00  217.00  227.0
# preseason   75.0   87.0  104.00  117.00  134.00  153.00  167.00  182.0
# ratio        0.5    0.5    0.54    0.63    0.65    0.72    0.77    0.8

# %%
regular_season_df['year'].apply(str)
# Out:
# 0       2018
# 1       2011
# 2       2014
# 3       2015
# 4       2016
#         ...
# 2449    2014
# 2450    2015
# 2451    2016
# 2452    2017
# 2453    2018
# Name: year, Length: 2454, dtype: object

# %%
regular_season_df['batter_name']
# Out:
# 0       가르시아
# 1        강경학
# 2        강경학
# 3        강경학
# 4        강경학
#         ...
# 2449     황진수
# 2450     황진수
# 2451     황진수
# 2452     황진수
# 2453     황진수
# Name: batter_name, Length: 2454, dtype: object

# %%
regular_season_df['new_idx'] = regular_season_df['batter_name'] + regular_season_df['year'].apply(str)
preseason_df['new_idx'] = preseason_df['batter_name'] + preseason_df['year'].apply(str)

intersection_idx = list(set(regular_season_df['new_idx']).intersection(preseason_df['new_idx']))

regular_season_new = regular_season_df.loc[
    regular_season_df['new_idx'].apply(lambda x: x in intersection_idx)
].copy()
regular_season_new = regular_season_new.sort_values(by='new_idx').reset_index(drop=True)

preseason_new = preseason_df.loc[
    preseason_df['new_idx'].apply(lambda x: x in intersection_idx)
].copy()
preseason_new = preseason_new.sort_values(by='new_idx').reset_index(drop=True)

print(regular_season_new.shape, preseason_new.shape)
sum(regular_season_new['new_idx'] == preseason_new['new_idx'])
# Out:
# (1358, 30) (1358, 30)
# 1358

# %%
correlation = regular_season_new['OPS'].corr(preseason_new['OPS'])
sns.scatterplot(regular_season_new['OPS'], preseason_new['OPS'])
plt.title('correlation: ' + str(np.round(correlation, 2)), fontsize=20)
plt.xlabel('정규시즌 OPS', fontsize=12)
plt.ylabel('프리시즌 OPS', fontsize=12)
plt.show()
# Out:
# C:\Users\dmlfo\anaconda3\envs\practice-ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
